# %% [markdown]
# # 3 Describing Data With Statistic

# %%
# Calculating the mean

def calculate_mean(numbers):
    s = sum(numbers)
    N = len(numbers)
    # Cacluate the mean
    mean = s/N
    
    return mean

if __name__ == '__main__':
    donations = [100, 60, 70, 900, 100, 200, 500, 500, 503, 600, 1000, 1200]
    mean = calculate_mean(donations)
    N = len(donations)
    print('Mean donation over the last {0} days is {1} '.format(N, mean))
# Out:
# Mean donation over the last 12 days is 477.75

# %%
# Calculating the median

def calculate_median(numbers):
    N = len(numbers)#1
    numbers.sort()#2
    
    # Find the median
    if N % 2 == 0 : 
        # if N is even
        m1 = N/2
        m2 = (N/2) + 1
        # Convert to integer, match position
        m1 = int(m1) - 1 #3
        m2 = int(m2) - 1 #4
        median = (numbers[m1] + numbers[m2])/2 #5
    else:
        m = (N+1)/2 #6
        # Convert to integer, match position
        m = int(m) - 1 
        median = numbers[m]
    return median

if __name__ == '__main__':
    donations = [100, 60, 70, 900, 100, 200, 500, 500, 503, 600, 1000, 1200]
    median = calculate_median(donations)
    N = len(donations)
    print('Median donation over the last {0} day is {1}'.format(N, median))
# Out:
# Median donation over the last 12 day is 500.0

# %%
# Calculating the mode


from collections import Counter

def calculate_mode(numbers):
    c = Counter(numbers) #1
    mode = c.most_common(1) #2
    return mode[0][0] #3

if __name__ == '__main__':
    scores = [7, 8, 2, 10, 9, 9, 9, 4, 5, 6, 1, 5, 6, 7, 8, 6, 1, 10,10,10]
    mode = calculate_mode(scores)
    
    print('The mode of the list of numbers is : {0}'.format(mode))
# Out:
# The mode of the list of numbers is : 10

# %%
# Calculating the mode when the list of numbers may  have multiple modes

from collections import Counter

def calculate_mode(numbers):
    
    c = Counter(numbers)
    numbers_freq = c.most_common() #1
    max_count = numbers_freq[0][1] #2
    
    modes = []
    for num in numbers_freq:
        if num[1] == max_count: # 3
            modes.append(num[0])
    return modes
        
if __name__ == '__main__':
    scores = [5, 5, 5, 4, 4, 4, 9, 1, 3,1,1]
    modes = calculate_mode(scores)
    print('The mode(s) of the list of numbers are: ')
    for mode in modes: #4
        print(mode)
# Out:
# The mode(s) of the list of numbers are:
# 5
# 4
# 1

# %%
# Frequncy table for a list of numbers

from collections import Counter

def frequency_table(numbers):
    table = Counter(numbers) #1
    print('Number\tFrequency')
    for number in table.most_common(): #2
        print('{0}\t{1}'.format(number[0], number[1]))
        
if __name__ == '__main__':
    scores = [7, 8, 9, 2, 10, 9, 9, 9, 9, 4, 5, 6, 1, 5, 6, 7, 8, 6, 1, 10]
    frequency_table(scores)
# Out:
# Number	Frequency
# 9	5
# 6	3
# 7	2
# 8	2
# 10	2
# 5	2
# 1	2
# 2	1
# 4	1

# %%
'''
Frequency table for a list of numbers
Enhanced to display the table sorted by the numbers
'''
from collections import Counter

def seringnya_table(numbers):
    table = Counter(numbers)
    numbers_freq = table.most_common()#1
    numbers_freq.sort()#2
    
    print('Number\tFrequency')
    for number in numbers_freq:#3
        print('{0}\t{1}'.format(number[0], number[1]))
if __name__ == '__main__':
    scores = [7, 8, 9, 2, 10, 9, 9, 9, 9, 4, 5, 6, 1, 5, 6, 7, 8, 6, 1, 10]
    seringnya_table(scores)
# Out:
# Number	Frequency
# 1	2
# 2	1
# 4	1
# 5	2
# 6	3
# 7	2
# 8	2
# 9	5
# 10	2

# %%
'''
Measuring the Dispersion
Find The Range
'''

def find_range(numbers):
    
    lowest = min(numbers)
    highest = max(numbers)
    # Find the range
    r = highest-lowest
    
    return lowest, highest, r

if __name__ == '__main__':
    donations = [100, 60, 70, 900, 100, 200, 500, 500, 503, 600, 1000, 1200]
    lowest, highest, r = find_range(donations)
    print('Lowest: {0} Highest: {1} Range: {2}'.format(lowest, highest, r))
# Out:
# Lowest: 60 Highest: 1200 Range: 1140

# %%
'''
Find the variance and standard deviation of a list of numbers
'''

def caculate_mean(numbers):
    s = sum(numbers)
    N = len(numbers)
    # Caculate mean
    mean = s/N
    
    return mean

def find_differences(numbers):
    # Find the mean
    mean = caculate_mean(numbers)
    # Find the diffrences from the mean
    diff = []
    for num in numbers:
        diff.append(num-mean)
    return diff

def caculate_variance(numbers):
    
    # Find the list of differences
    diff = find_differences(numbers) #1
    # Find the squared differences
    squared_diff = []
    for d in diff: #2
        squared_diff.append(d**2)
    # Find the Variance
    sum_squared_diff = sum(squared_diff)
    variance = sum_squared_diff/len(numbers) # 3
    return variance

if __name__ == '__main__':
    donations = [100, 60, 70, 900, 100, 200, 500, 500, 503, 600, 1000, 1200]
    variance = caculate_variance(donations)
    print('The variance of the list of numbers is {0}'.format(variance))
    
    std = variance**0.5 # 4
    print('The standard deviation of the list of numbers is {0}'.format(std))
# Out:
# The variance of the list of numbers is 141047.35416666666
# The standard deviation of the list of numbers is 375.5627166887931

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Calculating correlation coefficient

def find_corr_x_y(x,y):
    n = len(x)
    
    # Find the sum of the products
    prod = []
    for xi, yi in zip(x,y):#1
        prod.append(xi*yi)
    
    sum_prod_x_y = sum(prod)#2
    sum_x = sum(x)#3
    sum_y = sum(y)#4
    squared_sum_x = sum_x**2
    squared_sum_y = sum_y**2
    
    x_square = []
    for xi in x:#5
        x_square.append(xi**2)
    # Find the sum
    x_square_sum = sum(x_square)
    
    y_square=[]
    for yi in y:
        y_square.append(yi**2)
    # Find the sum
    y_square_sum = sum(y_square)
    
    # Use formula to calculate correlation
    numerator = n*sum_prod_x_y - sum_x*sum_y#6
    denominator_term1 = n*x_square_sum - squared_sum_x
    denominator_term2 = n*y_square_sum - squared_sum_y
    denominator = (denominator_term1*denominator_term2)**0.5#7
    correlation = numenator/denominator#8
    
    return correlation

# %%
'''
Reading Data from a text File
Find the sum of numbers stored in a file
'''

def sum_data(filename):
    s = 0
    with open(filename) as f:
        for line in f:
            s = s + float(line)
    print('Sum of the numbers: {0}'.format(s))

if __name__ == '__main__':
    sum_data("mydata.txt")
# Out:
# Sum of the numbers: 5733.0

# %%
# Calculating the mena of numbers stored in a file

def read_data(filename):
    
    numbers = []
    with open(filename) as f:
        for line in f:
            numbers.append(float(line))
    return numbers

def calculate_mean(numbers):
    s = sum(numbers)
    N = len(numbers)
    mean = s/N
    return mean

if __name__ == '__main__':
    data = read_data('mydata.txt')
    mean = caculate_mean(data)
    print('Mean {0}'.format(mean))
# Out:
# Mean 477.75

# %%
'''
Reading Data from a CSV File
'''
import csv
import matplotlib.pyplot as plt

def scatter_plot(x, y):
    plt.scatter(x, y)
    plt.xlabel('Number')
    plt.ylabel('Square')
    plt.show()
    
def read_csv(filename):
    
    with open(filename) as f:
        reader = csv.reader(f)
        next(reader)
        
        summer = []
        highest_correlated = []
        for row in reader:
            summer.append(float(row[1]))
            highest_correlated.append(float(row[2]))
    
    return summer, highest_correlated
    
    if __name__ == '__main__':
        summer, highest_correlated = read_csv('correlate-summer.csv')
        corr = find_corr_x_y(summer, highest_correlated)
        print('Highest correlation: {0}'.format(corr))
        scatter_plot(summer, highest_correlated)

# %% [markdown]
# # Programming Challenges

# %% [markdown]
# ## 1: Better Correlation Coefficient-Finding Program
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %%
'''
Linear correlation program
'''
def find_corr_x_y(x,y):
    
    if len(x) != len(y):
        print('The two sets of numbers are of  unequal size')
        return None
    n = len(x)

    # find the sum of the products
    prod = [xi*yi for xi, yi in zip(x, y)]
    sum_prod_x_y = sum(prod)

    # sum of the numbers in x
    sum_x = sum(x)
    # sum of the numbers in y
    sum_y = sum(y)

    # square of the sum if the numbers in x
    squared_sum_x = sum_x**2
    # square of the sum if the numbers in y
    squared_sum_y = sum_y**2

    # find the squares of numbers in x and the sum of the squares
    x_square = [xi**2 for xi in x]
    x_square_sum = sum(x_square)

    # find the squares of numbers in y and the sum of the squares
    y_square = [yi**2 for yi in y]
    y_square_sum = sum(y_square)

    # numerator
    numerator = n*sum_prod_x_y - sum_x*sum_y
    denominator_term1 = n*x_square_sum - squared_sum_x
    denominator_term2 = n*y_square_sum - squared_sum_y
    denominator = (denominator_term1*denominator_term2)**0.5
    correlation = numerator/denominator

    return correlation
    
    corr = find_corr_x_y(x,y)
    if not corr:
        print('Correlation could not be calculated')
    else:
        print('The correlation coefficient between x and y is {0}'.format(corr))

# %% [markdown]
# ## 2: Staistic Calculator
# ![image.png](attachment:image.png)

# %%
'''
Read numbers from a file, calculate and print statistical measure:
mean, median, mode, variance, standard deviation
'''

from stats import mean, median, mode, variance_sd

def read_data(filename):
    numbers = []
    with open(filename) as f:
        for line in f:
            numbers.append(float(line))
    return numbers

if __name__ == '__main__':
    data = read_data('mydata.txt')
    m = mean(data)
    median = median(data)
    mode = mode(data)
    variance, sd = variance_sd(data)
    
    
    print('Mean: {0:.5f}'.format(m))
    print('Median: {0:.5f}'.format(median))
    print('Mode: {0:.5f}'.format(mode))
    print('Variance: {0:.5f}'.format(variance))
    print('Standard deviation: {0:.5f}'.format(sd))
# Out:
# Mean: 477.75000
# Median: 500.00000
# Mode: 100.00000
# Variance: 141047.35417
# Standard deviation: 375.56272

# %% [markdown]
# # 3: Experiment with Other CSV Data
# ![image.png](attachment:image.png)

# %%
'''
Read the US population data from a CSV file, calculate the growth in population in consecutive years
and compute various statistical measures

Also creates two graphs - one showing the total population over the years and the other 
showing the change between
consecutive years
'''
import matplotlib.pyplot as plt
import csv

from stats import mean, median, variance_sd

def read_csv(filename):
    
    years = []
    population = []
    
    with open(filename) as f:
        reader = csv.reader(f)
        next(reader)
        
        summer = []
        highest_correlated = []
        
        for row in reader:
            # Eextract only the year from date
            year = row[0].split('-')[0] # 1
            years.append(year)
            population.append(float(row[1]))
    # Reverse the list because the orginal data lists the mostt recent years first
    population.reverse()
    years.reverse()
    
    return population, years

def plot_population(population, years):
    plt.figure(1)#2
    xaxis_positions = range(0, len(years))
    plt.plot(population, 'r-')
    plt.title('Total population in US')
    plt.xlabel('Year')
    plt.ylabel('Population')
    plt.xticks(xaxis_positions, years, rotation=45)#3
    
def caculate_stats(population):
    
    # find the growth in population in consecutive years
    growth = []
    for i in range(0, len(population)-1):
        growth.append(population[i+1] - population[i])
    print('Mean growth: {0:.5f}'.format(mean(growth)))
    print('Median growth: {0:.5f}'.format(median(growth)))
    print('Variance/Sd growth: {0:.5f}'.format(*variance_sd(growth)))
    return growth

def plot_population_diff(growth, years):
    
    xaxis_positions = range(0, len(years)-1)
    xaxis_labels = ['{0}-{1}'.format(years[i], years[i+1]) #4
                   for i in range(len(years)-1)]
    plt.figure(2)
    plt.plot(growth, 'r-')
    plt.title('Population Growth in consecutive years')
    plt.ylabel('Population Growth')
    plt.xticks(xaxis_positions, xaxis_labels, rotation=45)
    
if __name__ == '__main__':
    population, years = read_csv('USA_SP_POP_TOTL.csv')
    plot_population(population, years)
    growth = caculate_stats(population)
    plot_population_diff(growth, years)
    plt.show()
# Out:
# Mean growth: 2562366.15385
# Median growth: 2476370.00000
# Variance/Sd growth: 188985554755.28406

# %% [markdown]
# ## 4: Finding the prencentile
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
'''
Calculate the number from a list of numbers that corresponds to speciffic precentile
This implements the method described at
http://web.stanford.edu/class/archive/anthsci/anthsci192/anthsci192.1064/handouts/
calculating%20percentiles.pdf
'''

def find_percentile_score(data, percentile):
    if percentile < 0 or percentile > 100:
        return None
    data.sort()#1
    if percentile == 0:
        return data[0]
    if percentile == 100:
        return data[-1]
    
    n = len(data)
    i = ((n*percentile)/100) + 0.5#2
    
    if i.is_integer():
        real_idx = uint(i-1)
        return data[real_idx]#3
    else:
        k = int(i)#4
        f = i - k#5
        real_idx_1 = k - 1
        real_idx_2 = k
        return (1-f)*data[real_idx_1] + f*data[real_idx_2]#6
    
    
def read_data(filename):
    numbers = []
    with open(filename) as f:
        for line in f:
            numbers.append(float(line))
    return numbers

if __name__ == '__main__':
    percentile = float(input('Enter the percentile score you want to calculate: '))
    data = read_data('marks.txt')
    percentile_score = find_percentile_score(data, percentile)
    if percentile_score:
        print('The score at {0} percentile: {1}'.format(percentile, percentile_score))
    else:
        print('Could not find the score corresponding to {0} percentile'.format(percentile))
# Out:
# Enter the percentile score you want to calculate: 88
# The score at 88.0 percentile: 19.5

# %%
'''
Calculate the number from a list of numbers that corresponds
to a specific percentile

This implements the "Microsoft Excel Method":
https://en.wikipedia.org/wiki/Percentile#Microsoft_Excel_method
'''
def find_percentile_score(data, percentile):
    if percentile < 0 or percentile > 100:
        return None
    data.sort()
    if percentile == 0:
        return data[0]
    if percentile == 100:
        return data[-1]
    n = len(data)
    rank = (percentile/100)*(n-1) + 1#1
    k = int(rank)#2
    d = rank - k#3
    
    real_idx_1 = k-1
    real_idx_2 = k
    
    return data[real_idx_1] + d*(data[real_idx_2]-data[real_idx_1])#4

def read_data(filename):
    numbers = []
    with open(filename) as f:
        for line in f:
            numbers.append(float(line))
    return numbers

if __name__ == '__main__':
    percentile = float(input('Enter the percentile score you want to calculate: '))
    data = read_data('marks.txt')
    percentile_score = find_percentile_score(data, percentile)
    if percentile_score:
        print('The score at {0} percentile: {1}'.format(percentile, percentile_score))
    else:
        print('Could not find the score corresponding to {0} percentile'.format(percentile))
# Out:
# Enter the percentile score you want to calculate: 99.6
# The score at 99.6 percentile: 20.0

# %% [markdown]
# ## 5: Creating a Grouped Frequency Table
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
'''
Create a grouped frequncy tabel from a list of numbers
'''

def create_classes(numbers, n):
    low = min(numbers)
    high = max(numbers)
    
    # width of each class
    width = (high - low)/n
    classes = []
    a = low
    b = low + width
    classes = []
    while a < (high-width):
        classes.append((a,b))
        a = b
        b = a + width
    # The last class may be of size less than width
    classes.append((a, high+1))
    return classes
def classify(numbers, classes):
    # Create a list with the same number of elements as the number of classes
    count = [0]*len(classes)
    for n in numbers:
        for index, c in enumerate(classes):
            if n >= c[0] and n < c[1]:
                count[index] += 1
                break
    return count

def read_data(filename):
    numbers = []
    with open(filename) as f:
        for line in f:
            numbers.append(float(line))
    return numbers

if __name__ == '__main__':
    
    num_classes = int(input('Enter the number of classes: '))
    numbers = read_data('marks.txt')
    
    classes = create_classes(numbers, num_classes)
    count = classify(numbers, classes)
    for c, cnt in zip(classes, count):
        print('{0:.2f} - {1:.2f} \t {2}'.format(c[0], c[1], cnt))
# Out:
# Enter the number of classes: 4
# 10.50 - 12.88 	 4
# 12.88 - 15.25 	 4
# 15.25 - 17.62 	 7
# 17.62 - 21.00 	 10
